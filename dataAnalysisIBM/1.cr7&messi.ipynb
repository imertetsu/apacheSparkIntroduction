# %%
import pandas as pd

# %%
path = "D:\\Imer\\ProgrammingPractice\\Python\\Spark\\sparkIntroduction\\apacheSpark\\files\\goalsMessiCr7.csv"
df = pd.read_csv(path)
#para ver los 5 primeros resultados del dataframe
df.head()
# Out:
#               Player Season               Competition      Matchday  \
# 0  Cristiano Ronaldo  02/03             Liga Portugal             6
# 1  Cristiano Ronaldo  02/03             Liga Portugal             6
# 2  Cristiano Ronaldo  02/03             Liga Portugal             8
# 3  Cristiano Ronaldo  02/03  Taca de Portugal Placard  Fourth Round
# 4  Cristiano Ronaldo  02/03  Taca de Portugal Placard   Fifth Round
#
#          Date Venue         Club                 Opponent Result  \
# 0  2002-10-07     H  Sporting CP            Moreirense FC   3:00
# 1  2002-10-07     H  Sporting CP            Moreirense FC   3:00
# 2  2002-10-26     A  Sporting CP              Boavista FC   1:02
# 3  2002-11-24     H  Sporting CP             CD Estarreja   4:01
# 4  2002-12-18     H  Sporting CP  FC Oliveira do Hospital   8:01
#
#   Playing_Position Minute At_score               Type     Goal_assist
# 0               LW     34     2:00           Solo run             NaN
# ...

# %%
#para mostrar los tipos de datos de las columnas
df.dtypes
# Out:
# Player              object
# Season              object
# Competition         object
# Matchday            object
# Date                object
# Venue               object
# Club                object
# Opponent            object
# Result              object
# Playing_Position    object
# Minute              object
# At_score            object
# Type                object
# Goal_assist         object
# dtype: object

# %%
#Return a statistical summary
df.describe()
# Out:
#                    Player Season Competition     Matchday        Date Venue  \
# count                1413   1413        1413         1413        1413  1413
# unique                  2     22          21           53         821     2
# top     Cristiano Ronaldo  14/15      LaLiga  Group Stage  2013-01-27     H
# freq                  710    119         785          155           7   823
#
#                 Club    Opponent Result Playing_Position Minute At_score  \
# count           1413        1413   1413             1355   1413     1413
# unique             7         173     71               10    108       53
# top     FC Barcelona  Sevilla FC   3:00               CF     90     1:00
# freq             672          65     92              485     29      209
#
#                     Type  Goal_assist
# count               1397          953
# unique                12          159
# top     Left-footed shot  Luis Suarez
# freq                 549           48
